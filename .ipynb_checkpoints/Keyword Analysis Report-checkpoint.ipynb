# %% [markdown]
# ### Analysis Report

# %% [markdown]
# #### All the .csv files are in the following format - TweetId | Text | User_Id | Created_At

# %%
import pandas
# load the dataset

#Keyword1 Bitcoin
bitcoin_dataset = pandas.read_csv('Bitcoin.csv')
bitcoin_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
bitcoin_dataset.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369089123210825732  i’m excited to share my non profit organizatio...
# 1  1369089126901968901  its looking more and more likely that bitcoin ...
# 2  1369089134095138817  i’m happy my investors are benefiting from bit...
# 3  1369089136880140289  linkedin anniversary twitter facebook instagra...
# 4  1369089137966514183  meghanandharryonoprah or bitcoin or wsbmemes o...
#
#                   User            Timestamp
# 0            327888219  2021-03-09 00:54:18
# 1             90303704  2021-03-09 00:54:18
# 2  1212649284186718213  2021-03-09 00:54:20
# 3            617853906  2021-03-09 00:54:21
# 4  1367600719956742155  2021-03-09 00:54:21

# %% [markdown]
# ### Altcoin Keyword

# %%
#Keyword2 Altcoin
altcoin_dataset = pandas.read_csv('Altcoin.csv')
altcoin_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
altcoin_dataset.head()

# %% [markdown]
# ### Coindesk Keyword

# %%
#Keyword3 Coindesk
coindesk_dataset = pandas.read_csv('Coindesk.csv')
coindesk_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
coindesk_dataset.head()

# %% [markdown]
# ### Cryptocurrency Keyword

# %%
#Keyword4 Cryptocurrency
cryptocurrency_dataset = pandas.read_csv('Cryptocurrency.csv')
cryptocurrency_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
cryptocurrency_dataset.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369352156302737409  we cannot seize every opportunity if you encou...
# 1  1369352156118192133  the first digital currency you can mine on you...
# 2  1369352177907556354  felisartificus careless tech bro engineers may...
# 3  1369352178402553867  you make money by borrowing money btc bitcoin ...
# 4  1369352183272120320  omkarba sign up and get your new user bonus ch...
#
#                   User            Timestamp
# 0  1367936479456944130  2021-03-09 18:19:30
# 1            439332377  2021-03-09 18:19:30
# 2   964315233312497664  2021-03-09 18:19:35
# 3  1183409623690285062  2021-03-09 18:19:35
# 4  1320412372784324609  2021-03-09 18:19:36

# %% [markdown]
# ### Gold Keyword

# %%
#Keyword5 Gold
gold_dataset = pandas.read_csv('Gold.csv')
gold_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
gold_dataset.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369353033394622467  swiss s le mans k yellow gold diamond covered ...
# 1  1369353036213129231                          that woman only sees gold
# 2  1369353048473165829  a new supercycle is emerging heres how to play...
# 3  1369353054793986058  wait what didn’t notice that and i hope that w...
# 4  1369353056354197504  i needa stop being childish and learn cause al...
#
#                   User            Timestamp
# 0             29523749  2021-03-09 18:22:59
# 1           2563229064  2021-03-09 18:22:59
# 2            138513820  2021-03-09 18:23:02
# 3  1117040552145453057  2021-03-09 18:23:04
# 4            374749551  2021-03-09 18:23:04

# %% [markdown]
# ### APPL Keyword

# %%
#Keyword6 Gold
appl_dataset = pandas.read_csv('APPL.csv')
appl_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
appl_dataset.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369403563236032520                                      appl de phare
# 1  1369404011426820097  keelan my apple pie purchase will now be taxed...
# 2  1369407540719673354  trading ideas appl apple break down point be v...
# 3  1369407691127480322  central has a place for every scholar to resea...
# 4  1369407838712397842  honest affordable ice maker repairs near cityh...
#
#                   User            Timestamp
# 0  1279439679243378691  2021-03-09 21:43:46
# 1   936745672551882752  2021-03-09 21:45:33
# 2            121158213  2021-03-09 21:59:34
# 3             14845243  2021-03-09 22:00:10
# 4           1654654640  2021-03-09 22:00:45

# %% [markdown]
# ### GOOG Keyword

# %%
#Keyword7 GOOG
goog_dataset = pandas.read_csv('GOOG.csv')
goog_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
goog_dataset.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369354381615915013                titansventures abhicryptomedia goog
# 1  1369354387433398273  let’s spin the webull wheel shares of goog hav...
# 2  1369354402948145161  started trading with k down to k back up to k ...
# 3  1369354475098566657  let’s spin the webull wheel shares of goog hav...
# 4  1369354547232088064  bmy has a poor technical analysis score ta sco...
#
#                   User            Timestamp
# 0  1354548682180284418  2021-03-09 18:28:20
# 1           4617423140  2021-03-09 18:28:21
# 2  1369353784904871939  2021-03-09 18:28:25
# 3  1368545082161434628  2021-03-09 18:28:42
# 4            438262278  2021-03-09 18:29:00

# %% [markdown]
# ### YHOO Keyword

# %%
#Keyword8 YHOO
yhoo_dataset = pandas.read_csv('YHOO.csv')
yhoo_dataset.columns=["TweetId", "Tweet", "User", "Timestamp"] # Adding headers manually
yhoo_dataset.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369357058294878209                      portiias this video yhoo 🤣🤣🤣🤣
# 1  1369357205938536450  mercuse genu with whos money yhoo httpstcocgpigpi
# 2  1369357316076670977  kyle lowry is fed up about the rampant trade s...
# 3  1369357714753785863                             yahoooooooooo is right
# 4  1369357899303165958  yahoonews natashabertrand “…except we’re poppi...
#
#                   User            Timestamp
# 0  1243626773482536967  2021-03-09 18:38:58
# 1           3364749971  2021-03-09 18:39:33
# 2            312091763  2021-03-09 18:40:00
# 3   873865093536030720  2021-03-09 18:41:35
# 4            345464332  2021-03-09 18:42:19

# %% [markdown]
# ### Join all the data

# %%
frames = [bitcoin_dataset, altcoin_dataset, coindesk_dataset, cryptocurrency_dataset, gold_dataset, appl_dataset, goog_dataset, yhoo_dataset]
result = pandas.concat(frames)
result.head()
# Out:
#                TweetId                                              Tweet  \
# 0  1369089123210825732  i’m excited to share my non profit organizatio...
# 1  1369089126901968901  its looking more and more likely that bitcoin ...
# 2  1369089134095138817  i’m happy my investors are benefiting from bit...
# 3  1369089136880140289  linkedin anniversary twitter facebook instagra...
# 4  1369089137966514183  meghanandharryonoprah or bitcoin or wsbmemes o...
#
#                   User            Timestamp
# 0            327888219  2021-03-09 00:54:18
# 1             90303704  2021-03-09 00:54:18
# 2  1212649284186718213  2021-03-09 00:54:20
# 3            617853906  2021-03-09 00:54:21
# 4  1367600719956742155  2021-03-09 00:54:21

# %% [markdown]
# ### Fetch Word Count for each Tweet

# %%
dataset['word_count'] = dataset['Tweet'].apply(lambda x: len(str(x).split(" ")))
dataset[['Tweet','word_count']].head()
# Out:
#                                                Tweet  word_count
# 0  i’m excited to share my non profit organizatio...          36
# 1  its looking more and more likely that bitcoin ...          27
# 2  i’m happy my investors are benefiting from bit...          24
# 3  linkedin anniversary twitter facebook instagra...          30
# 4  meghanandharryonoprah or bitcoin or wsbmemes o...          12

# %% [markdown]
# ### Descriptive statistics of word counts

# %%
dataset.word_count.describe()
# Out:
# count    624.000000
# mean      20.807692
# std       13.116402
# min        1.000000
# 25%       10.000000
# 50%       18.000000
# 75%       31.000000
# max       62.000000
# Name: word_count, dtype: float64

# %% [markdown]
# # Average word count is 20

# %%
#Identify common words
freq = pandas.Series(' '.join(dataset['Tweet']).split()).value_counts()[:20]
freq
# Out:
# bitcoin           616
# to                309
# the               284
# and               222
# of                201
# a                 193
# you               173
# is                171
# crypto            161
# in                138
# on                129
# btc               117
# for               116
# i                 113
# k                  92
# your               86
# cryptocurrency     77
# free               74
# it                 72
# price              72
# dtype: int64

# %%
#Identify uncommon words
freq1 =  pandas.Series(' '.join(dataset 
         ['Tweet']).split()).value_counts()[-20:]
freq1
# Out:
# growth               1
# hourlycrypto         1
# crank                1
# avghprice            1
# dxy                  1
# marenaltman          1
# daysweeks            1
# generate             1
# fractions            1
# aid                  1
# dirty                1
# reaches              1
# grown                1
# samuelljackson       1
# spursofficial        1
# tucked               1
# httpstcoqswxmtpqn    1
# regulations          1
# put                  1
# api                  1
# dtype: int64

# %% [markdown]
# # Text Preprocessing

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sanjeet
# [nltk_data]     Pal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Sanjeet
# [nltk_data]     Pal\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
##Creating a list of stop words and adding custom stopwords
stop_words = set(stopwords.words("english"))
##Creating a list of custom stopwords
new_words = ["using", "show", "result", "large", "also", "iv", "one", "two", "new", "previously", "shown"]
stop_words = stop_words.union(new_words)

# %% [markdown]
# # Cleaning

# %%
corpus = []
for i in range(0, 623):
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', dataset['Tweet'][i])
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append(text)

# %% [markdown]
# # View corpus item

# %%
corpus[100]
# Out:
# 'daily morning market update th march investing market nifty sensex covid gold silver news joebiden pfizer moderna astrazeneca farmlaws wipro bitcoin stimuluschecks vaccine powell yield telecom spectrum airtel jio cairn pfizer httpstcoozifusuy'

# %% [markdown]
# # Word Cloud

# %%
#Word cloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
print(wordcloud)
fig = plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)

# %% [markdown]
# # Text preparation

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re
cv=CountVectorizer(max_df=0.8,stop_words=stop_words, max_features=10000, ngram_range=(1,3))
X=cv.fit_transform(corpus)

# %%
list(cv.vocabulary_.keys())[:10]
# Out:
# ['excited',
#  'share',
#  'non',
#  'profit',
#  'organization',
#  'raising',
#  'fund',
#  'help',
#  'black',
#  'swers']

# %% [markdown]
# # Most frequently occuring words

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]
#Convert most freq words to dataframe for plotting bar plot
top_words = get_top_n_words(corpus, n=20)
top_df = pandas.DataFrame(top_words)
top_df.columns=["Word", "Freq"]
#Barplot of most freq words
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
g = sns.barplot(x="Word", y="Freq", data=top_df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'bitcoin'),
#  Text(1, 0, 'crypto'),
#  Text(2, 0, 'btc'),
#  Text(3, 0, 'price'),
#  Text(4, 0, 'cryptocurrency'),
#  Text(5, 0, 'free'),
#  Text(6, 0, 'get'),
#  Text(7, 0, 'airdrop'),
#  Text(8, 0, 'earn'),
#  Text(9, 0, 'eth'),
#  Text(10, 0, 'like'),
#  Text(11, 0, 'money'),
#  Text(12, 0, 'start'),
#  Text(13, 0, 'ethereum'),
#  Text(14, 0, 'dogecoin'),
#  Text(15, 0, 'giveaway'),
#  Text(16, 0, 'latokens'),
#  Text(17, 0, 'buy'),
#  Text(18, 0, 'gift'),
#  Text(19, 0, 'gold')]

# %% [markdown]
# # Most frequently occuring Bi-grams

# %%
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top2_words = get_top_n2_words(corpus, n=20)
top2_df = pandas.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
print(top2_df)
#Barplot of most freq Bi-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
h=sns.barplot(x="Bi-gram", y="Freq", data=top2_df)
h.set_xticklabels(h.get_xticklabels(), rotation=45)
# Out:
#                     Bi-gram  Freq
# 0             bitcoin price    35
# 1               bitcoin btc    26
# 2                   btc eth    21
# 3              like bitcoin    21
# 4         youre considering    20
# 5                 earn free    20
# 6               free crypto    20
# 7              zil giveaway    20
# 8        latokenapp bitcoin    20
# 9                 free coin    19
# 10      nftrelated altcoins    18
# 11             altcoins hit    18
# 12                 hit high    18
# 13             high bitcoin    18
# 14              price rally    18
# 15    crypto cryptocurrency    17
# 16           bitcoin crypto    16
# 17                want earn    16
# 18              earn weekly    16
# 19  weekly cryptocurrencies    16
# [Text(0, 0, 'bitcoin price'),
#  Text(1, 0, 'bitcoin btc'),
#  Text(2, 0, 'btc eth'),
#  Text(3, 0, 'like bitcoin'),
#  Text(4, 0, 'youre considering'),
#  Text(5, 0, 'earn free'),
#  Text(6, 0, 'free crypto'),
#  Text(7, 0, 'zil giveaway'),
# ...
